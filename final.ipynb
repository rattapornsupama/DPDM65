# %% [markdown]
# <a href="https://colab.research.google.com/github/rattapornsupama/DPDM65/blob/main/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # import ไฟล์

# %%
 data = pd.read_csv('/content/drive/MyDrive/DPDM65/additional_data_newhouse.csv')

# %%
data.head()
# Out:
#    Unnamed: 0     id parent_id       project_name province      district  \
# 0           0  314.0      41.0  ที สเปซ กลางเมือง  ขอนแก่น  เมืองขอนแก่น
# 1           1  315.0      41.0  ที สเปซ กลางเมือง  ขอนแก่น  เมืองขอนแก่น
# 2           2  316.0      41.0  ที สเปซ กลางเมือง  ขอนแก่น  เมืองขอนแก่น
# 3           3  317.0      41.0  ที สเปซ กลางเมือง  ขอนแก่น  เมืองขอนแก่น
# 4           4  318.0      41.0  ที สเปซ กลางเมือง  ขอนแก่น  เมืองขอนแก่น
#
#   sub_district  zip_code  zone_id                          zone  ...  \
# 0    เมืองเก่า       NaN      5.0  กลางเมือง-เมืองเก่า-กุดกว้าง  ...
# 1    เมืองเก่า       NaN      5.0  กลางเมือง-เมืองเก่า-กุดกว้าง  ...
# 2    เมืองเก่า       NaN      5.0  กลางเมือง-เมืองเก่า-กุดกว้าง  ...
# 3    เมืองเก่า       NaN      5.0  กลางเมือง-เมืองเก่า-กุดกว้าง  ...
# 4    เมืองเก่า       NaN      5.0  กลางเมือง-เมืองเก่า-กุดกว้าง  ...
#
#   cable_range cable_min  cable_max  cable_free  cable_none cable_ask  \
# 0         NaN       NaN        NaN         NaN         NaN       NaN
# 1         NaN       NaN        NaN         NaN         NaN       NaN
# 2         NaN       NaN        NaN         NaN         NaN       NaN
# 3         NaN       NaN        NaN         NaN         NaN       NaN
# 4         NaN       NaN        NaN         NaN         NaN       NaN
#
#   position_previous position_current  sold_out_at  is_pro_in_house
# 0               0.0              0.0          NaN              0.0
# 1               0.0              0.0          NaN              0.0
# 2               0.0              0.0          NaN              0.0
# 3               0.0              0.0          NaN              0.0
# 4               0.0              0.0          NaN              0.0
#
# [5 rows x 139 columns]

# %%
data[['company','sell_price']]
# Out:
#                                 company  sell_price
# 0    บริษัท ที สเปซ พร๊อพเพอร์ตี้ จำกัด   3950000.0
# 1    บริษัท ที สเปซ พร๊อพเพอร์ตี้ จำกัด   3250000.0
# 2    บริษัท ที สเปซ พร๊อพเพอร์ตี้ จำกัด   6300000.0
# 3    บริษัท ที สเปซ พร๊อพเพอร์ตี้ จำกัด   6900000.0
# 4    บริษัท ที สเปซ พร๊อพเพอร์ตี้ จำกัด   4490000.0
# ..                                  ...         ...
# 988                                 NaN   1990000.0
# 989                                 NaN   1390000.0
# 990                                 NaN   1990000.0
# 991                                 NaN   1850000.0
# 992                                 NaN   2490000.0
#
# [993 rows x 2 columns]

# %%
set(data['property_type'])
# Out:
# {'คอนโด', 'ทาวน์โฮม', 'บ้านเดี่ยว', 'บ้านแฝด', 'อาคารพาณิชย์'}

# %%
data1=data[['zone_id','company_id','usable_area','number_of_story','number_of_bedroom','number_of_bathroom','number_of_parking','sell_price']]
data1
# Out:
#      zone_id  company_id  usable_area  number_of_story  number_of_bedroom  \
# 0        5.0        18.0        185.0              2.0                4.0
# 1        5.0        18.0        165.0              2.0                4.0
# 2        5.0        18.0        260.0              2.0                4.0
# 3        5.0        18.0        343.0              2.0                6.0
# 4        5.0        18.0        223.0              2.0                4.0
# ..       ...         ...          ...              ...                ...
# 988      NaN         NaN        120.0              1.0                3.0
# 989      NaN         NaN         96.0              1.0                2.0
# 990      NaN         NaN        100.0              1.0                3.0
# 991      NaN         NaN          NaN              2.0                2.0
# 992      NaN         NaN        138.0              1.0                3.0
#
#      number_of_bathroom  number_of_parking  sell_price
# 0                   3.0                2.0   3950000.0
# 1                   3.0                2.0   3250000.0
# 2                   3.0                2.0   6300000.0
# 3                   5.0                3.0   6900000.0
# 4                   4.0                2.0   4490000.0
# ..                  ...                ...         ...
# 988                 2.0                2.0   1990000.0
# 989                 1.0                2.0   1390000.0
# 990                 2.0                2.0   1990000.0
# 991                 2.0                NaN   1850000.0
# 992                 2.0                2.0   2490000.0
#
# [993 rows x 8 columns]

# %%
#data1['pricearea']=data1['sell_price']/(data1['usable_area]*1)
